# %%
import pandas as pd
import numpy as np

orcl_1d_data = pd.read_csv('TV_NYSE_ORCL_1D.csv')

# %%
print(orcl_1d_data.head())

print(orcl_1d_data.columns)
# Out:
#          time      open      high       low     close  MA  SMA-based MA  MA.1  \
# 0  1986-03-12  0.063273  0.063273  0.063273  0.063273 NaN           NaN   NaN
# 1  1986-03-13  0.064816  0.064816  0.064816  0.064816 NaN           NaN   NaN
# 2  1986-03-14  0.067131  0.067131  0.067131  0.067131 NaN           NaN   NaN
# 3  1986-03-17  0.065588  0.065588  0.065588  0.065588 NaN           NaN   NaN
# 4  1986-03-18  0.064044  0.064044  0.064044  0.064044 NaN           NaN   NaN
#
#    MA.2  MA.3  New Moon  Full Moon  MA.4  SMA-based MA.1  EMA  EMA.1  EMA.2  \
# 0   NaN   NaN         0          0   NaN             NaN  NaN    NaN    NaN
# 1   NaN   NaN         0          0   NaN             NaN  NaN    NaN    NaN
# 2   NaN   NaN         0          0   NaN             NaN  NaN    NaN    NaN
# 3   NaN   NaN         0          0   NaN             NaN  NaN    NaN    NaN
# 4   NaN   NaN         0          0   NaN             NaN  NaN    NaN    NaN
#
#    EMA.3  True Strength Index  Signal
# ...
